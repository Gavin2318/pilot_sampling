# %%
import pandas as pd
import numpy as np 

# %matplotlib inline
import matplotlib
import seaborn as sns
from sklearn.externals import joblib
import random

import matplotlib.pyplot as plt
from IPython.display import HTML, display

# %%
base_data = pd.read_csv('./data/policies.csv')

# %%
base_data.D_

# %% [markdown]
# # Select all the policies exp in 201805 to 201807

# %%
exp_pols = base_data[(base_data.D_EXP_YRM>=201805)&(base_data.D_EXP_YRM<=201807)
                     &(base_data.LOB=='001-Private Motor')&(base_data.NEW_DC=='Agents')].copy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-e814665f9364> in <module>()
#       1 exp_pols = base_data[(base_data.D_EXP_YRM>=201805)&(base_data.D_EXP_YRM<=201807)
# ----> 2                      &(base_data.LOB=='001-Private Motor')&(base_data.NEW_DC=='Agents')].copy()
#
# /anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'D_EXP_YRM'

# %%
print('Number of total policies expires in 201805 to 201807: ' + str(exp_pols.shape[0]))
print('Number of Agency for these policies: ' + str(exp_pols.SOURCE_CODE.nunique()))
# Out:
# Number of total policies expires in 201805 to 201807: 24466
# Number of Agency for these policies: 498

# %%
exp_pols.SOURCE_CODE.value_counts(dropna=False)
# Out:
# ANDA INSURANCE AGENCIES PTE LTD           3110
# INSMART (INSURANCE) AGENCY PTE LTD        1131
# G & M PTE LTD                              973
# ARF (ASIA PACIFIC) PTE LTD                 934
# META AGENCY PTE LTD                        740
# DICKSON AUTO AGENCY                        704
# WINNER INSURANCE AGENCIES PTE LTD          637
# S & M ALLIANCE PTE LTD                     616
# KHC HOLDINGS PTE LTD                       560
# MAXURANCE VENTURE                          537
# INSURE LINK PTE LTD                        527
# MDIVINE INSURANCE AGENCY                   444
# ALFA CREDIT PTE LTD                        430
# LQ INSURANCE AGENCY PTE LTD                342
# INSURE HUB PTE LTD                         335
# B.A.S ENTERPRISE                           329
# SAFE HARBOUR ASSURANCE AGENCY              293
# INXPRESS INSURANCE AGENCY PTE LTD          277
# ALPINE CREDIT PTE LTD                      272
# HOBBES INSURANCE AGENCY                    270
# IVAN INSURANCE AGENCY                      264
# J G MOTOR AGENCY                           238
# ALL INS SOLUTIONS PTE LTD                  236
# AXA LIFE INSURANCE SINGAPORE               228
# SD CONTEGO SERVICES                        226
# VINCAR PTE LTD                             210
# ALLINK INSURANCE AGENCY                    197
# CAR TIMES INSURANCE AGENCY PTE LTD         182
# HENLY ENTERPRISES CO PTE LTD               175
# JETTA INSURANCE AGENCY PTE LTD             166
#                                           ...
# GLC RISK MANAGEMENT                          1
# NG SWEE NGHEE MARTIN                         1
# RASEM TEO & PARTNER INSURANCE AGENCY         1
# KAO SZE JWEN GRACE                           1
# KHOO FOO WAH KELVIN                          1
# CHEW KAI PIN                                 1
# CHEW CHEN XIN                                1
# ULTRA PROTECTION SERVICES PTE LTD            1
# KO HUAT MENG                                 1
# GOH TECK CHYE ANTHONY                        1
# GAN YOK CHUN SAM                             1
# URBAN GENERAL INSURANCE AGENCY               1
# CHIN KIM FOOK JOHNNY                         1
# INTERNATIONAL PROTECTION GROUP PTE LTD       1
# ICOVER SERVICES                              1
# TEO CHOON HONG                               1
# POH HUN HOCK                                 1
# WELLBRIDGE HOLDINGS PTE LTD                  1
# MMS SERVICES PTE LTD                         1
# CHENG CHOONG KHAN                            1
# K K LEE & ASSOCIATES                         1
# WEE CHENG HOE APOLLO                         1
# WAVEROCK CONSULTANTS PTE LTD                 1
# CORPORATE SOLUTIONS ADVISORY PTE LTD         1
# SEAH MONG YEOW LESLIE                        1
# ONE 5 TREE                                   1
# GOH BOCK SENG                                1
# CITIPOINT CREDIT (S) PTE LTD                 1
# REGO INSURANCE AGENCY PTE LTD                1
# NG, MENG LIAN MELVYN                         1
# Name: SOURCE_CODE, dtype: int64

# %% [markdown]
# # Key features

# %%
# Differnce bwtween GWP_RENWEE and GWP_RENWIE? Differnce bwtween GWP_NBZEE and GWP_NBZIE? 
# GWP_RENWEE: GWP for a Renewal policy (excl. endorsements = at issuance)
# GWP_RENWIE: GWP for a Renewal policy incl. endorsements)
# GWP_NBZEE: GWP for a New Business policy (excl. endorsements = at issuance)
# GWP_NBZIE: GWP for a New Business policy (incl. endorsements)

# %%
exp_pols['D_BIRTH_PY'] = exp_pols['D_BIRTH_PY'].fillna(pd.to_datetime('1800-01-01'))
exp_pols['clt_age'] = exp_pols.apply(lambda row: 
        round(pd.Timedelta(pd.to_datetime(row['D_EXP_PY']) - pd.to_datetime(row['D_BIRTH_PY'])).days/ 365.0) , axis=1)
exp_pols.loc[exp_pols['clt_age']>90, 'clt_age'] = np.NaN
exp_pols['clt_age'] = exp_pols['clt_age'].fillna(exp_pols.clt_age.median())

# %%
exp_pols['YRMANF']= exp_pols['YRMANF'].replace(0, 1800)
exp_pols['YRMANF'] = exp_pols['YRMANF'].apply(lambda x: str(int(x)))
exp_pols['car_age'] = exp_pols.apply(lambda row: 
        round(pd.Timedelta(pd.to_datetime(row['D_EXP_PY']) - pd.to_datetime(row['YRMANF'])).days/ 365.0) , axis=1)
exp_pols.loc[exp_pols['car_age']>20, 'car_age'] = np.NaN
exp_pols['car_age'] = exp_pols['car_age'].fillna(exp_pols.car_age.median())

# %%
exp_pols['gwp'] = exp_pols['GWP_NBZIE'] + exp_pols['GWP_RENWIE']
exp_pols['high_end'] = exp_pols['CONTRACT_TYPE'].apply(lambda x : int(x=='Private High End Cars'))

# %%
# age, gender, gwp, experian grp, 
# vehicle YRMANF, ZMAKE (To be use: CAPCTY )
continus_features = ['clt_age',  'gwp', 'car_age', 'CAPCTY']
cate_features = ['CLTSEX','ZMAKE', 'PC_M_SG_17_GROUP_ALPHA_I', 'high_end']
key_features = continus_features + cate_features

# %% [markdown]
# # Select agents

# %% [markdown]
# - select all the policies exp in 201710 to 201712

# %%
int_list = []
for i in range(source_codes.shape[0]):
    a = random.randint(0, 2)
    int_list.append(a)
    source_codes.iloc[i, 2] = a
display(source_codes.groupby('group_nb').sum())
exp_pols_wth_grp = exp_pols.merge(source_codes)
# Out:
#           nb_pols
# group_nb
# 0            6368
# 1            6743
# 2            6555

# %%
# source_codes.to_csv('/group/axa_sg/motor_retention/sxi/quck_win/agent_groups/Source_code_grp_v1.csv', index=False)

# %% [markdown]
# # Check similarity bwtween 3 groups

# %% [markdown]
# ### cancel rate, lapse rate,  nb pol exp in 2017

# %%
def get_cancel_rate(dataset):
    nb_renewable = dataset['PCEXP_RNABL_CANC'].sum() + dataset['PCEXP_RNABL_LAPS'].sum(
                        ) + dataset['PCEXP_RNABL_RENW'].sum() + dataset['PCEXP_RNABL_REPL'].sum()
    nb_cancel = dataset['PCEXP_RNABL_CANC'].sum()
    cancel_rate = nb_cancel*1.0/ nb_renewable
    return cancel_rate

def get_lapse_rate(dataset):
    nb_total = dataset['PCEXP_RNABL_LAPS'].sum(
                        ) + dataset['PCEXP_RNABL_RENW'].sum() + dataset['PCEXP_RNABL_REPL'].sum()
    nb_lapse = dataset['PCEXP_RNABL_LAPS'].sum()
    lapse_rate = nb_lapse*1.0/ nb_total
    return lapse_rate

# %%
# int_list = []
# for i in range(source_codes.shape[0]):
#     a = random.randint(0, 2)
#     int_list.append(a)
#     source_codes.iloc[i, 2] = a
# display(source_codes.groupby('group_nb').sum())
# exp_pols_wth_grp = exp_pols.merge(source_codes)

# base_2017 = base_data.loc[(base_data.LOB=='001-Private Motor')&(base_data.D_EXP_YR==2017)].copy()
# base_2017 = base_2017.merge(source_codes)

# agency_grp_stas = pd.DataFrame(columns=['agency_grp', 'nb_exp', 'cancel_rate', 'lapse_rate'])
# agency_grp_stas['agency_grp'] =[0,1,2]

# for grp in [0,1,2]:
#     agency_grp_stas.loc[agency_grp_stas.agency_grp== grp, 'nb_exp'] = base_2017.loc[base_2017.group_nb==grp].shape[0]
#     agency_grp_stas.loc[agency_grp_stas.agency_grp== grp, 'cancel_rate'] = get_cancel_rate(
#         base_2017.loc[base_2017.group_nb==grp])
#     agency_grp_stas.loc[agency_grp_stas.agency_grp== grp, 'lapse_rate'] = get_lapse_rate(
#         base_2017.loc[base_2017.group_nb==grp])
    
    
# agency_grp_stas

# %% [markdown]
# - get the good splitting

# %%
def coef_of_var(x):
    return np.std(x)/np.mean(x)

# %%
source_codes =  pd.DataFrame(exp_pols.SOURCE_CODE.value_counts(dropna=False)).reset_index(
            ).rename(columns={'index':'SOURCE_CODE', 'SOURCE_CODE':'nb_pols'})
source_codes['group_nb'] = 0

# %%
good_seed = [11,86]

# %%
good_seed = []
for j in [11,86]:
    random.seed(j)
    int_list = []
    for i in range(source_codes.shape[0]):
        a = random.randint(0, 2)
        int_list.append(a)
        source_codes.iloc[i, 2] = a
#     display(source_codes.groupby('group_nb').sum())
    exp_pols_wth_grp = exp_pols.merge(source_codes)
    
    #########################
    base_2017 = base_data.loc[(base_data.LOB=='001-Private Motor')&(base_data.D_EXP_YR==2017)].copy()
    base_2017 = base_2017.merge(source_codes)

    agency_grp_stas = pd.DataFrame(columns=['agency_grp', 'nb_exp', 'cancel_rate', 'lapse_rate'])
    agency_grp_stas['agency_grp'] =[0,1,2]

    for grp in [0,1,2]:
        agency_grp_stas.loc[agency_grp_stas.agency_grp== grp, 'nb_exp'] = base_2017.loc[base_2017.group_nb==grp].shape[0]
        agency_grp_stas.loc[agency_grp_stas.agency_grp== grp, 'cancel_rate'] = get_cancel_rate(
            base_2017.loc[base_2017.group_nb==grp])
        agency_grp_stas.loc[agency_grp_stas.agency_grp== grp, 'lapse_rate'] = get_lapse_rate(
            base_2017.loc[base_2017.group_nb==grp])
    
#     display(agency_grp_stas)
    
    
    var_metric = coef_of_var(source_codes.groupby('group_nb').sum()['nb_pols'].values)*0.1 + coef_of_var(
        agency_grp_stas['cancel_rate'].values)*0.5 + coef_of_var(agency_grp_stas['lapse_rate'].values)
    
#     print("Round %d: "%(j+1) +  str(var_metric))
    
    if((j+1)%10==0):
        print("Round %d finished! "%(j+1))
    
#     if(var_metric<=0.05):
#         print("Seed range 0.05: "+str(j))
    
#     if(var_metric<=0.04):
#         print("Seed range 0.04: "+str(j))
    
    if(var_metric<=0.05):
        print('Random seed: %d'%(j))
        display(source_codes.groupby('group_nb').sum())
        display(agency_grp_stas)
        print(var_metric)
#         good_seed.append(j)
#         break
# Out:
# Random seed: 11
#           nb_pols
# group_nb
# 0            6973
# 1           11555
# 2            5938
#    agency_grp nb_exp cancel_rate lapse_rate
# 0           0  30388     0.15997   0.355167
# 1           1  42852    0.162433   0.353998
# 2           2  22243    0.167319   0.349606
# 0.0460669195157
# Random seed: 86
#           nb_pols
# group_nb
# 0            8700
# 1            5223
# 2           10543
#    agency_grp nb_exp cancel_rate lapse_rate
# 0           0  37361    0.163892   0.352339
# 1           1  19738    0.167756   0.355412
# 2           2  38384    0.159151   0.353288
# 0.0414345649387

# %%
source_codes.to_csv('/group/axa_sg/motor_retention/sxi/quck_win/agent_groups/Source_code_grp_v1.csv', index=False)

# %% [markdown]
# ## Key features distribution

# %%
def compare_cate_variable(dataset, value_col, grp_col, nb_top_values, percentage=True):
    top_values = pd.DataFrame(dataset[value_col].value_counts()).reset_index()[:nb_top_values]['index'].values
    
    cate_data = dataset.groupby([value_col, grp_col]).size().reset_index().rename(columns={0:'number'})
    grp_size = cate_data.groupby(['group_nb']).sum().reset_index().rename(columns = {'number':'grp_size'})
    cate_data = cate_data.merge(grp_size)
    cate_data['percentage'] = cate_data['number']*1.0/cate_data['grp_size']
    cate_data = cate_data.loc[cate_data[value_col].isin(top_values)]
    
#     plt.figure(figsize=(16, 9))
    if (percentage == False):
        sns.barplot(x=value_col, y="number", hue=grp_col, data=cate_data)
    else:
        sns.barplot(x=value_col, y="percentage", hue=grp_col, data=cate_data)
    plt.xticks(rotation=45)

# %%
# compare_cate_variable(exp_pols_wth_grp, 'ZMAKE', 'group_nb', 15)

# %%
# exp_pols_wth_grp[exp_pols_wth_grp['SOURCE_CODE'] =='G & M PTE LTD'].ZMAKE.value_counts()
# exp_pols_wth_grp[exp_pols_wth_grp['ZMAKE'] =='PORSCHE'].SOURCE_CODE.value_counts()
# exp_pols_wth_grp[exp_pols_wth_grp['ZMAKE'] =='YAMAHA'].SOURCE_CODE.value_counts()

# compare_cate_variable(exp_pols_wth_grp, 'ZMAKE', 'group_nb', 10)
# compare_cate_variable(exp_pols_wth_grp, 'CLTSEX', 'group_nb', 10)

# top_makers = pd.DataFrame(exp_pols_wth_grp.ZMAKE.value_counts()).reset_index()[:15]['index'].values

# maker_data = exp_pols_wth_grp.groupby(['ZMAKE', 'group_nb']).size().reset_index().rename(columns={0:'nb_pols'})
# maker_data = maker_data.loc[maker_data.ZMAKE.isin(top_makers)]

# plt.figure(figsize=(16, 9))
# sns.barplot(x="ZMAKE", y="nb_pols", hue="group_nb", data=maker_data)
# plt.xticks(rotation=90)

# %%
# a4_dims = (18, 16)
# fig, axs = plt.subplots(ncols=2, nrows=4, figsize=a4_dims)
# for grp in [0,1,2]:
#     sns.distplot(exp_pols_wth_grp.loc[exp_pols_wth_grp['group_nb']==grp][col], ax=axs[0, 0])
#     sns.distplot(exp_pols_wth_grp.loc[exp_pols_wth_grp['group_nb']==grp]['car_age'], ax=axs[0,1])

# %%
plt.figure(figsize=(18, (len(key_features)/2+1)*6))
i = 1
for col in key_features:
    plt.subplot(len(key_features)/2+1, 2, i)
    if(col in continus_features):
        for grp in [0,1,2]:
            sns.distplot(exp_pols_wth_grp.loc[exp_pols_wth_grp['group_nb']==grp][col])
    else:
        compare_cate_variable(exp_pols_wth_grp, col, 'group_nb', 15)  
    i+=1

# %% [markdown]
# - The difference are mostly because YAMAHA motor and PORSCHE policies

# %%
exp_pols_wth_grp[exp_pols_wth_grp['ZMAKE'] =='YAMAHA'].SOURCE_CODE.value_counts()
# Out:
# ANDA INSURANCE AGENCIES PTE LTD    1234
# KHC HOLDINGS PTE LTD                  2
# Name: SOURCE_CODE, dtype: int64

# %%
exp_pols_wth_grp[exp_pols_wth_grp['SOURCE_CODE'] =='ANDA INSURANCE AGENCIES PTE LTD'].shape
# Out:
# (3110, 94)

# %%
exp_pols_wth_grp[exp_pols_wth_grp.CONTRACT_TYPE =='Private High End Cars'].SOURCE_CODE.value_counts()
# Out:
# G & M PTE LTD                         738
# SD CONTEGO SERVICES                    43
# KOMOCO(FERRARI SCHEME)                 14
# ARK INSURANCE AGENCY                    6
# MAXURANCE VENTURE                       5
# DICKSON AUTO AGENCY                     5
# IVAN INSURANCE AGENCY                   4
# KHC HOLDINGS PTE LTD                    3
# CHOY WENG HONG ERIC                     3
# DAGLEN GI PTE LTD                       2
# SPEEDO CAPITAL PTE LTD                  2
# IVENTURE MANAGEMENT PTE LTD             2
# TH INSURANCE AGENCY PTE LTD             2
# VC INSURANCE AGENCY PTE LTD             2
# TECK WEI CREDIT PTE LTD                 2
# I INSURANCE SG AGENCY                   2
# INSMART (INSURANCE) AGENCY PTE LTD      2
# ARF (ASIA PACIFIC) PTE LTD              1
# VILLAGE CREDIT PTE LTD                  1
# SCANWELL ASSOCIATES PTE LTD             1
# JIN-SHI (HOLDINGS) PTE LTD              1
# WELLFIELD INSURANCE AGENCY              1
# INSURE HUB PTE LTD                      1
# INSUREMYCAR.COM.SG                      1
# TRADLINK SOLUTIONS PTE LTD              1
# META AGENCY PTE LTD                     1
# HUI HUA CREDIT PTE LTD                  1
# E TAY TRADING COMPANY                   1
# URBAN INSURANCE AGENCY SERVICES         1
# ASTRA ASSURANCE AGENCIES LLP            1
# M PLUS SERVICES                         1
# UNIQUE RESOURCES PTE LTD                1
# GS ASSURANCE AGENCY PTE LTD             1
# J & T PLANNING SERVICES                 1
# TTS MOTOR GROUP PTE LTD                 1
# REV AUTO PTE LTD                        1
# AUTOBAHN MOTORS (S) PTE LTD             1
# VIRTUAL INSURANCE AGENCIES PTE LTD      1
# AXA LIFE INSURANCE SINGAPORE            1
# KOMOCO TRADING PTE LTD                  1
# MANICKAM SUPERMANIAM JAMES              1
# ANG WEI HEAN                            1
# MDIVINE INSURANCE AGENCY                1
# INSURE LINK PTE LTD                     1
# LEE PENG KOON LIONEL                    1
# B P PHILOMO PTE LTD                     1
# GRINWEIV ALLIANCE PTE LTD               1
# EASTERN INSURANCE AGENCY PTE LTD        1
# S & M ALLIANCE PTE LTD                  1
# ALLINK INSURANCE AGENCY                 1
# ASSURA PTE LTD                          1
# INSURED UNITED AGENCY PTE LTD           1
# CHUA SWEE HIOK PRISCILLA                1
# Name: SOURCE_CODE, dtype: int64

# %%
exp_pols_wth_grp[exp_pols_wth_grp.SOURCE_CODE =='G & M PTE LTD'].CONTRACT_TYPE.value_counts()
# Out:
# Private High End Cars     738
# GTOM Private Cars COMP    181
# Private Cars COMP          33
# GTOM Private Cars TPO      15
# GTOM Private Cars TPFT      3
# Motorcycle COMP             1
# Private Cars TPO            1
# Motorcycle TPO              1
# Name: CONTRACT_TYPE, dtype: int64

# %%
exp_pols_wth_grp[exp_pols_wth_grp['ZMAKE'] =='YAMAHA'].SOURCE_CODE.value_counts()

# %%
exp_pols_wth_grp.CONTRACT_TYPE.value_counts()
# Out:
# GTOM Private Cars COMP    17506
# Private Cars COMP          2216
# Motorcycle TPFT            1628
# Motorcycle TPO             1018
# Private High End Cars       873
# GTOM Private Cars TPO       499
# Motorcycle COMP             419
# GTOM Private Cars TPFT      279
# Private Cars TPO             19
# Private Cars TPFT             9
# Name: CONTRACT_TYPE, dtype: int64
